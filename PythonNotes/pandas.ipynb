# %% [markdown]
# # Pandas Basics
#
# ## Pandas Documentation
#
# A common library used to manipulate data.
# Most problems can be solved by viewing the documentation.
# <https://pandas.pydata.org/docs/>

# %%
import pandas as pd;
import numpy as np;
